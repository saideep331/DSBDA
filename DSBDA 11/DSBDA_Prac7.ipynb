# %%
sentence1 = "I will walk 500 miles and I would walk 500 more. Just to be the thousand."
sentence2 = "I played the play playfully as the players were playing in the field."

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk import word_tokenize, sent_tokenize

# %%
print("Tokenized words: ", word_tokenize(sentence1))
# Out:
# Tokenized words:  ['I', 'will', 'walk', '500', 'miles', 'and', 'I', 'would', 'walk', '500', 'more', '.', 'Just', 'to', 'be', 'the', 'thousand', '.']

# %%
print("Tokenized sentence: ", sent_tokenize(sentence1))
# Out:
# Tokenized sentence:  ['I will walk 500 miles and I would walk 500 more.', 'Just to be the thousand.']

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk import pos_tag
token=word_tokenize(sentence1) + word_tokenize(sentence2)

# %%
print("POS tagged: ", pos_tag(token))
# Out:
# POS tagged:  [('I', 'PRP'), ('will', 'MD'), ('walk', 'VB'), ('500', 'CD'), ('miles', 'NNS'), ('and', 'CC'), ('I', 'PRP'), ('would', 'MD'), ('walk', 'VB'), ('500', 'CD'), ('more', 'JJR'), ('.', '.'), ('Just', 'NNP'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('thousand', 'NN'), ('.', '.'), ('I', 'PRP'), ('played', 'VBD'), ('the', 'DT'), ('play', 'NN'), ('playfully', 'RB'), ('as', 'IN'), ('the', 'DT'), ('players', 'NNS'), ('were', 'VBD'), ('playing', 'VBG'), ('in', 'IN'), ('the', 'DT'), ('field', 'NN'), ('.', '.')]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop_words=set(stopwords.words('english'))
token=word_tokenize(sentence1)
cleaned_token=[]
for word in token:
  if word not in stop_words:
    cleaned_token.append(word)
print("Unclean version: ", token)
print("\n")
print("Cleaned version:  ",cleaned_token)
# Out:
# Unclean version:  ['I', 'will', 'walk', '500', 'miles', 'and', 'I', 'would', 'walk', '500', 'more', '.', 'Just', 'to', 'be', 'the', 'thousand', '.']
#
#
# Cleaned version:   ['I', 'walk', '500', 'miles', 'I', 'would', 'walk', '500', '.', 'Just', 'thousand', '.']

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
token = word_tokenize(sentence2)
stemmed = [stemmer.stem(word) for word in token]
print("Stemmed words: ", stemmed)
# Out:
# Stemmed words:  ['i', 'play', 'the', 'play', 'play', 'as', 'the', 'player', 'were', 'play', 'in', 'the', 'field', '.']

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
token = word_tokenize(sentence2)
lemmatized = [lemmatizer.lemmatize(word) for word in token]
print("Lemmatized words: ", lemmatized)
# Out:
# Lemmatized words:  ['I', 'played', 'the', 'play', 'playfully', 'a', 'the', 'player', 'were', 'playing', 'in', 'the', 'field', '.']
